# %%
df = pd.read_csv("roster_20250916.csv")

# %%
# import pandas as pd

df = pd.read_csv("roster_20250916.csv")

# %%
import pandas as pd

df = pd.read_csv("roster_20250916.csv")

# %%
df

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:
df[0:4]

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:
print()

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:
print(df[0:4])

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:
print(df[0:4])
# output:

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:
print(df[0:4])
# output:

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:
print(df[0:4])

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:
print(df.columns)
print(df[0:4])

# %%
import pandas as pd

df = pd.read_csv("roster_20250916.csv", header=2)

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:
print(df.columns)
print(df[0:4])

# %%
import pandas as pd

df = pd.read_csv("roster_20250916.csv", header=1)

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:
print(df.columns)
print(df[0:4])

# %%
# span the rows properly
df = df.rename(columns={
    ' ': 'ID',
    'Unnamed: 6': 'not_supposed_to_exist',
})
# move values in rows with null ID to the correct columns
df_blanks_mask = df['ID'].isnull()
df_copy_unmod = df.copy(deep=True)
df.loc[df_blanks_mask, 'Parent/Guardian Name '] = df_copy_unmod.loc[df_blanks_mask, 'First Name']
df.loc[df_blanks_mask, 'Address'] = df_copy_unmod.loc[df_blanks_mask, 'Parent/Guardian Name ']
df.loc[df_blanks_mask, 'Home Phone'] = df_copy_unmod.loc[df_blanks_mask, 'Address']
df.loc[df_blanks_mask, 'Email'] = df_copy_unmod.loc[df_blanks_mask, 'not_supposed_to_exist']
df

# %%
import pandas as pd

df = pd.read_csv("roster_20250916.csv", header=1)

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:
print(df.columns)
print(df[0:4])

# %%
# span the rows properly
df = df.rename(columns={
    ' ': 'ID',
    'Unnamed: 6': 'not_supposed_to_exist',
})
# move values in rows with null ID to the correct columns
df_blanks_mask = df['ID'].isnull()
df_copy_unmod = df.copy(deep=True)
df.loc[df_blanks_mask, 'Parent/Guardian Name '] = df_copy_unmod.loc[df_blanks_mask, 'Den']
df.loc[df_blanks_mask, 'Address'] = df_copy_unmod.loc[df_blanks_mask, 'Parent/Guardian Name ']
df.loc[df_blanks_mask, 'Home Phone'] = df_copy_unmod.loc[df_blanks_mask, 'Address']
df.loc[df_blanks_mask, 'Email'] = df_copy_unmod.loc[df_blanks_mask, 'not_supposed_to_exist']
df

# %%
# span the rows properly
df = df.rename(columns={
    ' ': 'ID',
    'Unnamed: 6': 'not_supposed_to_exist',
})
# move values in rows with null ID to the correct columns
df_blanks_mask = df['ID'].isnull()
df_copy_unmod = df.copy(deep=True)
df.loc[df_blanks_mask, 'Parent/Guardian Name '] = df_copy_unmod.loc[df_blanks_mask, 'Den']
df.loc[df_blanks_mask, 'Den'] = None
df.loc[df_blanks_mask, 'Address'] = df_copy_unmod.loc[df_blanks_mask, 'Parent/Guardian Name ']
df.loc[df_blanks_mask, 'Home Phone'] = df_copy_unmod.loc[df_blanks_mask, 'Address']
df.loc[df_blanks_mask, 'Email'] = df_copy_unmod.loc[df_blanks_mask, 'not_supposed_to_exist']
df =df.drop(columns=['not_supposed_to_exist', 'Unnamed: 11'])

# fill forward

# %%
# span the rows properly
df = df.rename(columns={
    ' ': 'ID',
    'Unnamed: 6': 'not_supposed_to_exist',
})
# move values in rows with null ID to the correct columns
df_blanks_mask = df['ID'].isnull()
df_copy_unmod = df.copy(deep=True)
df.loc[df_blanks_mask, 'Parent/Guardian Name '] = df_copy_unmod.loc[df_blanks_mask, 'Den']
df.loc[df_blanks_mask, 'Den'] = None
df.loc[df_blanks_mask, 'Address'] = df_copy_unmod.loc[df_blanks_mask, 'Parent/Guardian Name ']
df.loc[df_blanks_mask, 'Home Phone'] = df_copy_unmod.loc[df_blanks_mask, 'Address']
df.loc[df_blanks_mask, 'Email'] = df_copy_unmod.loc[df_blanks_mask, 'not_supposed_to_exist']
df =df.drop(columns=['not_supposed_to_exist', 'Unnamed: 11'])
df
# fill forward

# %%
import pandas as pd

df = pd.read_csv("roster_20250916.csv", header=1)

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:
print(df.columns)
print(df[0:4])
# output:
"""
Index([' ', 'First Name', 'Last Name', 'Den', 'Parent/Guardian Name ',
       'Address', 'Unnamed: 6', 'Home Phone', 'Work Phone', 'Mobile Phone',
       'Email', 'Unnamed: 11'],
      dtype='object')
 First Name   Last Name              Den Parent/Guardian Name   \
0  1.0     Eloise     Akerman           Bear 1        Jessie Akerman   
1  NaN        NaN         NaN  Michael Akerman       504 Averette Rd   
2  2.0     Oliver  Balikowski        Webelos 5     Adrian Balikowski   
3  3.0      Jamie     Ballard     99 LOST CUBS          Joan Ballard   

                  Address                  Unnamed: 6           Home Phone  \
0         504 Averette Rd                         NaN  (919) 268-3093 home   
1   (919) 417-7849 mobile  michaelakerman@pack500.org                  NaN   
2     204 Red Cardinal Ct                         NaN                  NaN   
3      2710 Langstroth Ct                         NaN  (919) 798-8022 home   

  Work Phone           Mobile Phone                        Email  Unnamed: 11  
0        NaN  (919) 268-3093 mobile    breazealejessie@gmail.com          NaN  
1        NaN                    NaN                          NaN          NaN  
2        NaN  (203) 828-8008 mobile  Adrian.balikowski@gmail.com          NaN  
3        NaN  (919) 798-8022 mobile  jmballard102001@hotmail.com          NaN  
"""

# %%
# span the rows properly
df = df.rename(columns={
    ' ': 'ID',
    'Unnamed: 6': 'not_supposed_to_exist',
})
# move values in rows with null ID to the correct columns
df_blanks_mask = df['ID'].isnull()
df_copy_unmod = df.copy(deep=True)
df.loc[df_blanks_mask, 'Parent/Guardian Name '] = df_copy_unmod.loc[df_blanks_mask, 'Den']
df.loc[df_blanks_mask, 'Den'] = None
df.loc[df_blanks_mask, 'Address'] = df_copy_unmod.loc[df_blanks_mask, 'Parent/Guardian Name ']
df.loc[df_blanks_mask, 'Home Phone'] = df_copy_unmod.loc[df_blanks_mask, 'Address']
df.loc[df_blanks_mask, 'Email'] = df_copy_unmod.loc[df_blanks_mask, 'not_supposed_to_exist']
df =df.drop(columns=['not_supposed_to_exist', 'Unnamed: 11'])
df
# fill forward

# %%
# span the rows properly
df = df.rename(columns={
    ' ': 'ID',
    'Unnamed: 6': 'not_supposed_to_exist',
})
# move values in rows with null ID to the correct columns
df_blanks_mask = df['ID'].isnull()
df_copy_unmod = df.copy(deep=True)
df.loc[df_blanks_mask, 'Parent/Guardian Name '] = df_copy_unmod.loc[df_blanks_mask, 'Den']
df.loc[df_blanks_mask, 'Den'] = None
df.loc[df_blanks_mask, 'Address'] = df_copy_unmod.loc[df_blanks_mask, 'Parent/Guardian Name ']
df.loc[df_blanks_mask, 'Home Phone'] = df_copy_unmod.loc[df_blanks_mask, 'Address']
df.loc[df_blanks_mask, 'Email'] = df_copy_unmod.loc[df_blanks_mask, 'not_supposed_to_exist']
df =df.drop(columns=['not_supposed_to_exist', 'Unnamed: 11'])
# fill forward First Name and Last Name
df['First Name'] = df['First Name'].fillna(method='ffill')
df['Last Name'] = df['Last Name'].fillna(method='ffill')
df

# %%
import pandas as pd

df = pd.read_csv("roster_20250916.csv", header=1)

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:
print(df.columns)
print(df[0:4])

# %%
# span the rows properly
df = df.rename(columns={
    ' ': 'ID',
    'Unnamed: 6': 'not_supposed_to_exist',
})
# move values in rows with null ID to the correct columns
df_blanks_mask = df['ID'].isnull()
df_copy_unmod = df.copy(deep=True)
df.loc[df_blanks_mask, 'Parent/Guardian Name '] = df_copy_unmod.loc[df_blanks_mask, 'Den']
df.loc[df_blanks_mask, 'Den'] = None
df.loc[df_blanks_mask, 'Address'] = df_copy_unmod.loc[df_blanks_mask, 'Parent/Guardian Name ']
df.loc[df_blanks_mask, 'Home Phone'] = df_copy_unmod.loc[df_blanks_mask, 'Address']
df.loc[df_blanks_mask, 'Email'] = df_copy_unmod.loc[df_blanks_mask, 'not_supposed_to_exist']
df =df.drop(columns=['not_supposed_to_exist', 'Unnamed: 11'])
# fill forward First Name and Last Name
df['First Name'] = df['First Name'].fillna(method='ffill')
df['Last Name'] = df['Last Name'].fillna(method='ffill')
df

# %%
import pandas as pd

df = pd.read_csv("roster_20250916.csv", header=1)

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:
print(df.columns)
print(df[0:4])

# %%
# span the rows properly
df = df.rename(columns={
    ' ': 'ID',
    'Unnamed: 6': 'not_supposed_to_exist',
})
# move values in rows with null ID to the correct columns
df_blanks_mask = df['ID'].isnull()
df_copy_unmod = df.copy(deep=True)
df.loc[df_blanks_mask, 'Parent/Guardian Name '] = df_copy_unmod.loc[df_blanks_mask, 'Den']
df.loc[df_blanks_mask, 'Den'] = None
df.loc[df_blanks_mask, 'Address'] = df_copy_unmod.loc[df_blanks_mask, 'Parent/Guardian Name ']
df.loc[df_blanks_mask, 'Home Phone'] = df_copy_unmod.loc[df_blanks_mask, 'Address']
df.loc[df_blanks_mask, 'Email'] = df_copy_unmod.loc[df_blanks_mask, 'not_supposed_to_exist']
df =df.drop(columns=['not_supposed_to_exist', 'Unnamed: 11'])
# fill forward First Name and Last Name and Den
df['First Name'] = df['First Name'].fillna(method='ffill')
df['Last Name'] = df['Last Name'].fillna(method='ffill')
df["Den"] = df["Den"].fillna(method='ffill')

# %%
df.to_csv("roster_20250916_fixed.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("roster_20250916.csv", header=1)

# %%
# some rows start with null values in the first unnamed column. In these cases, the rows are for the same scout as the nearest populated row above.
# in addition, the columns are offset:
print(df.columns)
print(df[0:4])

# %%
# span the rows properly
df = df.rename(columns={
    ' ': 'ID',
    'Unnamed: 6': 'not_supposed_to_exist',
})
# move values in rows with null ID to the correct columns
df_blanks_mask = df['ID'].isnull()
df_copy_unmod = df.copy(deep=True)
df.loc[df_blanks_mask, 'Parent/Guardian Name '] = df_copy_unmod.loc[df_blanks_mask, 'Den']
df.loc[df_blanks_mask, 'Den'] = None
df.loc[df_blanks_mask, 'Address'] = df_copy_unmod.loc[df_blanks_mask, 'Parent/Guardian Name ']
df.loc[df_blanks_mask, 'Home Phone'] = df_copy_unmod.loc[df_blanks_mask, 'Address']
df.loc[df_blanks_mask, 'Email'] = df_copy_unmod.loc[df_blanks_mask, 'not_supposed_to_exist']
df =df.drop(columns=['not_supposed_to_exist', 'Unnamed: 11'])
# fill forward First Name and Last Name and Den and id
df['First Name'] = df['First Name'].fillna(method='ffill')
df['Last Name'] = df['Last Name'].fillna(method='ffill')
df["Den"] = df["Den"].fillna(method='ffill')
df["ID"] = df["ID"].fillna(method='ffill')

# %%
df.to_csv("roster_20250916_fixed.csv", index=False)

# %%
df_missing_people = df.read_csv("2025 Fall Campout Registration (Responses) - Missing.csv")

# %%
df_missing_people = pd.read_csv("2025 Fall Campout Registration (Responses) - Missing.csv")

# %%
df_missing_people

# %%
df.groupby("Last Name").agg({"Email": lambda x: ";".join(x.unique().tolist())})

# %%
df_missing_people.groupby("Last Name").agg({"Email": lambda x: ";".join(x.unique().tolist())})

# %%
df_missing_people.groupby("Last Name").agg({"Email": lambda x: ";".join(x.unique().tolist()), "Parent/Guardian Name ": " and ".join(x.split(" ")[0])})

# %%
df_missing_people.groupby("Last Name").agg({"Email": lambda x: ";".join(x.unique().tolist()), "Parent/Guardian Name ": lambda x: " and ".join(x.split(" ")[0])})

# %%
df_missing_people

# %%
df_missing_people.groupby("Last Name").agg({"Email": lambda x: ";".join(x.unique().tolist()), "Parent/Guardian Name": lambda x: " and ".join(x.split(" ")[0])})

# %%
df_missing_people.groupby("Last Name").agg({"Email": lambda x: ";".join(x.unique().tolist()), "Parent/Guardian Name": lambda x: " and ".join(x.str.split(" ")[0])})

# %%
df_missing_people.groupby("Last Name").agg({"Email": lambda x: ";".join(x.unique().tolist()), "Parent/Guardian Name": lambda x: " and ".join([name.split(" ")[0] for name in x.unique().tolist()])})

# %%
df_missing_people.groupby("Last Name").agg({"Email": lambda x: ";".join(x.unique().tolist()), "Parent/Guardian Name": lambda x: " and ".join([name.split(" ")[0] for name in x.unique().tolist()])}).to_csv('mailmerge.csv')

# %%
df_missing_people.groupby("Email").agg({"Parent/Guardian Name": lambda x: " and ".join([name.split(" ")[0] for name in x.unique().tolist()])}).to_csv('mailmerge.csv')

# %%
df_missing_people.groupby("Email").agg(first_name=("Parent/Guardian Name", lambda x: " and ".join([name.split(" ")[0] for name in x.unique().tolist()])), last_name=("Parent/Guardian Name", lambda x: " and ".join([name.split(" ")[0:] for name in x.unique().tolist()]))).to_csv('mailmerge.csv')

# %%
df_missing_people.groupby("Email").agg({"Parent/Guardian Name": "first"})

# %%
df_mail_merge = df_missing_people.groupby("Email").agg({"Parent/Guardian Name": "first"})

# %%
df_mail_merge["first"] = df_mail_merge['Parent/Guardian Name'].str.split().explode()

# %%
df_mail_merge_explode = df_mail_merge['Parent/Guardian Name'].str.split().explode()

# %%
df

# %%
df_mail

# %%
df_mail_merge_explode

# %%
df_missing_people.drop_duplicates(subset='email')

# %%
df_missing_people.drop_duplicates(subset='Email')

# %%
df_missing_people.drop_duplicates(subset='Email')['Email', 'Parent/Guardian Name']

# %%
df_missing_people.drop_duplicates(subset='Email')[['Email', 'Parent/Guardian Name']]

# %%
df_mail_merge = df_missing_people.drop_duplicates(subset='Email')[['Email', 'Parent/Guardian Name']]

# %%
df_mail_merge['firstname'] = df_mail_merge['Parent/Guardian Name'].str.split().str[0]

# %%
df_mail_merge

# %%
df_mail_merge['lastname'] = df_mail_merge['Parent/Guardian Name'].str.split().str[0:]

# %%
df_mail_merge

# %%
df_mail_merge['lastname'] = df_mail_merge['Parent/Guardian Name'].str.split().str[1:].str.join(" ")

# %%
df

# %%
df_mail_merge

# %%
df_mail_merge.to_csv("mailmerge.csv")
